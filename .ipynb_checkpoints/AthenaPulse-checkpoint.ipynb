# %% [markdown]
# # Business Understanding

# %% [markdown]
# # Data Acquisition and Understanding

# %% [markdown]
# ## DSO1

# %% [markdown]
# ## DSO2

# %% [markdown]
# ## DSO3

# %% [markdown]
# ## DSO4

# %% [markdown]
# # Modeling

# %% [markdown]
# ## DSO1

# %% [markdown]
# ## DSO2

# %% [markdown]
# ## DSO3

# %% [markdown]
# ## DSO4

# %% [markdown]
# # Deployment
